# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.18.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /workspaces/codespaces-jupyter/Minecraft-server
# JVM info: Microsoft - 21.0.2 - 21.0.2+13-LTS
# java.net.preferIPv4Stack=true
# Current Time: 13/03/2024 19:50:57
# Host: files.minecraftforge.net [51.79.83.165]
# Host: maven.minecraftforge.net [51.79.83.165]
# Host: libraries.minecraft.net [13.107.213.41, 13.107.246.41]
# Host: launchermeta.mojang.com [13.107.213.41, 13.107.246.41]
# Host: piston-meta.mojang.com [13.107.246.41, 13.107.213.41]
# Host: sessionserver.mojang.com [13.107.213.41, 13.107.246.41]
# Host: authserver.mojang.com [Unknown]
# Target Directory: .
# Data kindly mirrored by CreeperHost at https://www.creeperhost.net/
# Considering minecraft server jar
# Downloading libraries
# Found 0 additional library directories
# Considering library cpw.mods:securejarhandler:1.0.8
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm:9.5
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-commons:9.5
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-tree:9.5
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-util:9.5
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-analysis:9.5
#   File exists: Checksum validated.
# Considering library net.minecraftforge:accesstransformers:8.0.4
#   File exists: Checksum validated.
# Considering library org.antlr:antlr4-runtime:4.9.1
#   File exists: Checksum validated.
# Considering library net.minecraftforge:eventbus:5.0.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:forgespi:4.0.15-4.x
#   File exists: Checksum validated.
# Considering library net.minecraftforge:coremods:5.0.1
#   File exists: Checksum validated.
# Considering library cpw.mods:modlauncher:9.1.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:unsafe:0.2.0
#   File exists: Checksum validated.
# Considering library com.electronwill.night-config:core:3.6.4
#   File exists: Checksum validated.
# Considering library com.electronwill.night-config:toml:3.6.4
#   File exists: Checksum validated.
# Considering library org.apache.maven:maven-artifact:3.6.3
#   File exists: Checksum validated.
# Considering library net.jodah:typetools:0.8.3
#   File exists: Checksum validated.
# Considering library net.minecrell:terminalconsoleappender:1.2.0
#   File exists: Checksum validated.
# Considering library org.jline:jline-reader:3.12.1
#   File exists: Checksum validated.
# Considering library org.jline:jline-terminal:3.12.1
#   File exists: Checksum validated.
# Considering library org.spongepowered:mixin:0.8.5
#   File exists: Checksum validated.
# Considering library org.openjdk.nashorn:nashorn-core:15.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:JarJarSelector:0.3.19
#   File exists: Checksum validated.
# Considering library net.minecraftforge:JarJarMetadata:0.3.19
#   File exists: Checksum validated.
# Considering library cpw.mods:bootstraplauncher:1.0.0
#   File exists: Checksum validated.
# Considering library net.minecraftforge:JarJarFileSystems:0.3.19
#   File exists: Checksum validated.
# Considering library net.minecraftforge:fmlloader:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library com.github.jponge:lzma-java:1.3
#   File exists: Checksum validated.
# Considering library com.google.code.findbugs:jsr305:3.0.2
#   File exists: Checksum validated.
# Considering library com.google.code.gson:gson:2.8.7
#   File exists: Checksum validated.
# Considering library com.google.errorprone:error_prone_annotations:2.1.3
#   File exists: Checksum validated.
# Considering library com.google.guava:guava:20.0
#   File exists: Checksum validated.
# Considering library com.google.guava:guava:25.1-jre
#   File exists: Checksum validated.
# Considering library com.google.j2objc:j2objc-annotations:1.1
#   File exists: Checksum validated.
# Considering library com.nothome:javaxdelta:2.0.1
#   File exists: Checksum validated.
# Considering library com.opencsv:opencsv:4.4
#   File exists: Checksum validated.
# Considering library commons-beanutils:commons-beanutils:1.9.3
#   File exists: Checksum validated.
# Considering library commons-collections:commons-collections:3.2.2
#   File exists: Checksum validated.
# Considering library commons-io:commons-io:2.4
#   File exists: Checksum validated.
# Considering library commons-logging:commons-logging:1.2
#   File exists: Checksum validated.
# Considering library de.oceanlabs.mcp:mcp_config:1.18.2-20220404.173914@zip
#   File exists: Checksum validated.
# Considering library de.siegmar:fastcsv:2.0.0
#   File exists: Checksum validated.
# Considering library net.md-5:SpecialSource:1.11.0
#   File exists: Checksum validated.
# Considering library net.minecraftforge:ForgeAutoRenamingTool:0.1.25:all
#   File exists: Checksum validated.
# Considering library net.minecraftforge:binarypatcher:1.0.12
#   File exists: Checksum validated.
# Considering library net.minecraftforge:fmlcore:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:fmlloader:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:forge:1.18.2-40.2.17:universal
#   File exists: Checksum validated.
# Considering library net.minecraftforge:installertools:1.3.0
#   File exists: Checksum validated.
# Considering library net.minecraftforge:jarsplitter:1.1.4
#   File exists: Checksum validated.
# Considering library net.minecraftforge:javafmllanguage:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:lowcodelanguage:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:mclanguage:1.18.2-40.2.17
#   File exists: Checksum validated.
# Considering library net.minecraftforge:srgutils:0.4.11
#   File exists: Checksum validated.
# Considering library net.minecraftforge:srgutils:0.4.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:srgutils:0.4.9
#   File exists: Checksum validated.
# Considering library net.sf.jopt-simple:jopt-simple:5.0.4
#   File exists: Checksum validated.
# Considering library net.sf.jopt-simple:jopt-simple:6.0-alpha-3
#   File exists: Checksum validated.
# Considering library org.apache.commons:commons-collections4:4.2
#   File exists: Checksum validated.
# Considering library org.apache.commons:commons-lang3:3.8.1
#   File exists: Checksum validated.
# Considering library org.apache.commons:commons-text:1.3
#   File exists: Checksum validated.
# Considering library org.checkerframework:checker-qual:2.0.0
#   File exists: Checksum validated.
# Considering library org.codehaus.mojo:animal-sniffer-annotations:1.14
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-analysis:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-analysis:9.3
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-commons:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-commons:9.3
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-tree:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-tree:9.3
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm:9.3
#   File exists: Checksum validated.
# Considering library trove:trove:1.0.2
#   File exists: Checksum validated.
# Created Temporary Directory: /tmp/forge_installer4504056349116267938
#   Extracting: /data/server.lzma
# Building Processors
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, EXTRACT_FILES, --archive, /workspaces/codespaces-jupyter/Minecraft-server/forge.jar, --from, data/run.sh, --to, /workspaces/codespaces-jupyter/Minecraft-server/./run.sh, --exec, /workspaces/codespaces-jupyter/Minecraft-server/./run.sh, --from, data/run.bat, --to, /workspaces/codespaces-jupyter/Minecraft-server/./run.bat, --from, data/user_jvm_args.txt, --to, /workspaces/codespaces-jupyter/Minecraft-server/./user_jvm_args.txt, --optional, /workspaces/codespaces-jupyter/Minecraft-server/./user_jvm_args.txt, --from, data/win_args.txt, --to, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.18.2-40.2.17/win_args.txt, --from, data/unix_args.txt, --to, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.18.2-40.2.17/unix_args.txt
# Task: EXTRACT_FILES
# Archive: /workspaces/codespaces-jupyter/Minecraft-server/forge.jar
# Extract: data/run.sh
#          /workspaces/codespaces-jupyter/Minecraft-server/./run.sh
# Extract: data/run.bat
#          /workspaces/codespaces-jupyter/Minecraft-server/./run.bat
# Extract: data/user_jvm_args.txt
#          /workspaces/codespaces-jupyter/Minecraft-server/./user_jvm_args.txt
# Extract: data/win_args.txt
#          /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.18.2-40.2.17/win_args.txt
# Extract: data/unix_args.txt
#          /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.18.2-40.2.17/unix_args.txt
# Exec:    /workspaces/codespaces-jupyter/Minecraft-server/./run.sh
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, BUNDLER_EXTRACT, --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2/server-1.18.2.jar, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/, --libraries
# Task: BUNDLER_EXTRACT
# Input:   /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2/server-1.18.2.jar
# Output:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries
# All:     false
# JarOnly: false
# Libs:    true
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, BUNDLER_EXTRACT, --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2/server-1.18.2.jar, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-unpacked.jar, --jar-only
# Task: BUNDLER_EXTRACT
# Input:   /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2/server-1.18.2.jar
# Output:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-unpacked.jar
# All:     false
# JarOnly: true
# Libs:    false
# File already exists, and hash verified
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, MCP_DATA, --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914.zip, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings.txt, --key, mappings
# Task: MCP_DATA
# Input:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914.zip
# Output: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings.txt
# Key:    mappings
# Extracting: config/joined.tsrg
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, DOWNLOAD_MOJMAPS, --version, 1.18.2, --side, server, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-mappings.txt
# Task: DOWNLOAD_MOJMAPS
# MC Version: 1.18.2
# Side:       server
# Output:     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-mappings.txt
# Downloaded Mojang mappings for 1.18.2
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.3.0/installertools-1.3.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/md-5/SpecialSource/1.11.0/SpecialSource-1.11.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/5.0.4/jopt-simple-5.0.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.8.7/gson-2.8.7.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.0.0/fastcsv-2.0.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.11/srgutils-0.4.11.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.3/asm-commons-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/guava/guava/20.0/guava-20.0.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/opencsv/opencsv/4.4/opencsv-4.4.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.3/asm-analysis-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.3/asm-tree-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.3/asm-9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-text/1.3/commons-text-1.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-lang3/3.8.1/commons-lang3-3.8.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-beanutils/commons-beanutils/1.9.3/commons-beanutils-1.9.3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/apache/commons/commons-collections4/4.2/commons-collections4-4.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-logging/commons-logging/1.2/commons-logging-1.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
#   Args: --task, MERGE_MAPPING, --left, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings.txt, --right, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-mappings.txt, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings-merged.txt, --classes, --reverse-right
# Task: MERGE_MAPPING
# Left:    /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings.txt
#          Reversed=false
#          null
# Right:   /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-mappings.txt
#          Reversed=true
#          null
# Classes: true
# Fields:  false
# Methods: false
# Params:  false
# Output:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings-merged.txt
# ===============================================================================
#   Cache:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-slim.jar Validated: 92c652fa6f3574b07d31ab22696c2dbdcd0c4c04
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-extra.jar Validated: 4f1ba0161f6d78345feaf2f469abf809ee18cd9f
#   Cache Hit!
# ===============================================================================
#   MainClass: net.minecraftforge.fart.Main
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/ForgeAutoRenamingTool/0.1.25/ForgeAutoRenamingTool-0.1.25-all.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/6.0-alpha-3/jopt-simple-6.0-alpha-3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.2/asm-commons-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.2/asm-analysis-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.2/asm-tree-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.2/asm-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.9/srgutils-0.4.9.jar
#   Args: --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-slim.jar, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar, --names, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings-merged.txt, --ann-fix, --ids-fix, --src-fix, --record-fix
# Forge Auto Renaming Tool v0.1.25
# log: null
# input: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-slim.jar
# output: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar
# threads: 4
# Names: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.18.2-20220404.173914/mcp_config-1.18.2-20220404.173914-mappings-merged.txt(reversed: false)
# Fix Annotations: true
# Fix Records: true
# Fix Identifiers: ALL
# Fix SourceFile: JAVA
# Fix Line Numbers: false
# Strip codesigning signatures: false
# Adding Libraries to Inheritance
# Reading Input: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-slim.jar
# Adding input to inheritence map
# Processing entries
# Cant Find Class: org/slf4j/Logger
# Cant Find Class: javax/annotation/ParametersAreNonnullByDefault
# Cant Find Class: org/apache/commons/lang3/exception/ExceptionUtils
# Cant Find Class: com/google/common/base/MoreObjects
# Cant Find Class: javax/annotation/Nullable
# Cant Find Class: com/mojang/brigadier/Message
# Cant Find Class: com/google/common/collect/Lists
# Cant Find Class: com/mojang/authlib/GameProfile
# Cant Find Class: com/google/common/collect/Sets
# Cant Find Class: com/google/common/collect/Maps
# Cant Find Class: com/mojang/datafixers/util/Pair
# Cant Find Class: com/mojang/brigadier/exceptions/CommandSyntaxException
# Cant Find Class: com/google/common/collect/ImmutableList
# Cant Find Class: org/apache/commons/io/IOUtils
# Cant Find Class: com/mojang/serialization/Keyable
# Cant Find Class: com/mojang/logging/LogUtils
# Cant Find Class: com/google/common/escape/Escapers$Builder
# Cant Find Class: com/google/common/escape/Escapers
# Cant Find Class: com/google/common/escape/Escaper
# Cant Find Class: com/mojang/brigadier/CommandDispatcher
# Cant Find Class: com/mojang/brigadier/arguments/ArgumentType
# Cant Find Class: com/mojang/brigadier/StringReader
# Cant Find Class: com/mojang/brigadier/exceptions/SimpleCommandExceptionType
# Cant Find Class: com/mojang/brigadier/exceptions/CommandExceptionType
# Cant Find Class: com/mojang/brigadier/context/CommandContext
# Cant Find Class: com/mojang/brigadier/builder/LiteralArgumentBuilder
# Cant Find Class: com/mojang/brigadier/Command
# Cant Find Class: com/mojang/brigadier/suggestion/SuggestionsBuilder
# Cant Find Class: com/mojang/brigadier/builder/ArgumentBuilder
# Cant Find Class: com/mojang/brigadier/arguments/BoolArgumentType
# Cant Find Class: com/mojang/brigadier/builder/RequiredArgumentBuilder
# Cant Find Class: com/mojang/brigadier/arguments/IntegerArgumentType
# Cant Find Class: com/mojang/brigadier/arguments/StringArgumentType
# Cant Find Class: com/mojang/brigadier/tree/LiteralCommandNode
# Cant Find Class: org/apache/commons/lang3/mutable/MutableInt
# Cant Find Class: com/google/common/collect/Iterables
# Cant Find Class: com/google/common/collect/Streams
# Cant Find Class: com/mojang/brigadier/suggestion/Suggestions
# Cant Find Class: com/mojang/datafixers/DataFixer
# Cant Find Class: com/mojang/authlib/minecraft/MinecraftSessionService
# Cant Find Class: com/mojang/authlib/GameProfileRepository
# Cant Find Class: com/google/common/base/Stopwatch
# Cant Find Class: com/mojang/serialization/Lifecycle
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectSet
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectIterator
# Cant Find Class: it/unimi/dsi/fastutil/Hash$Strategy
# Cant Find Class: it/unimi/dsi/fastutil/Hash
# Cant Find Class: javax/annotation/Nonnull
# Cant Find Class: javax/annotation/meta/TypeQualifierDefault
# Cant Find Class: org/apache/commons/io/FilenameUtils
# Cant Find Class: com/google/gson/JsonDeserializer
# Cant Find Class: com/google/gson/JsonSerializer
# Cant Find Class: com/google/gson/JsonObject
# Cant Find Class: com/google/common/base/Ticker
# Cant Find Class: com/google/gson/JsonElement
# Cant Find Class: com/google/gson/JsonSyntaxException
# Cant Find Class: com/mojang/datafixers/DSL$TypeReference
# Cant Find Class: com/mojang/datafixers/DSL
# Cant Find Class: com/google/gson/JsonParseException
# Cant Find Class: io/netty/buffer/ByteBuf
# Cant Find Class: com/google/gson/JsonNull
# Cant Find Class: com/google/gson/JsonArray
# Cant Find Class: com/google/gson/JsonPrimitive
# Cant Find Class: com/google/common/collect/ImmutableMap
# Cant Find Class: com/google/common/util/concurrent/MoreExecutors
# Cant Find Class: com/google/common/util/concurrent/ListeningExecutorService
# Cant Find Class: com/mojang/datafixers/types/Type
# Cant Find Class: com/mojang/bridge/game/GameVersion
# Cant Find Class: com/mojang/datafixers/DataFixUtils
# Cant Find Class: com/mojang/datafixers/schemas/Schema
# Cant Find Class: com/google/gson/JsonSerializationContext
# Cant Find Class: com/google/gson/JsonDeserializationContext
# Cant Find Class: com/mojang/brigadier/ImmutableStringReader
# Cant Find Class: com/mojang/brigadier/exceptions/BuiltInExceptionProvider
# Cant Find Class: com/mojang/brigadier/exceptions/DynamicCommandExceptionType
# Cant Find Class: com/google/common/collect/ImmutableSet
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectArrayList
# Cant Find Class: com/google/common/collect/Iterators
# Cant Find Class: com/mojang/serialization/DataResult
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2BooleanMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2BooleanMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2BooleanOpenHashMap
# Cant Find Class: com/google/common/base/Joiner
# Cant Find Class: com/google/gson/Gson
# Cant Find Class: com/google/gson/GsonBuilder
# Cant Find Class: com/google/common/collect/Multimap
# Cant Find Class: com/google/common/collect/ImmutableSet$Builder
# Cant Find Class: com/mojang/serialization/Codec
# Cant Find Class: com/mojang/serialization/JsonOps
# Cant Find Class: com/mojang/serialization/DynamicOps
# Cant Find Class: org/apache/commons/lang3/ArrayUtils
# Cant Find Class: com/mojang/brigadier/ParseResults
# Cant Find Class: com/mojang/brigadier/context/CommandContextBuilder
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMap
# Cant Find Class: com/mojang/brigadier/tree/CommandNode
# Cant Find Class: com/mojang/brigadier/AmbiguityConsumer
# Cant Find Class: com/mojang/brigadier/ResultConsumer
# Cant Find Class: com/mojang/brigadier/tree/RootCommandNode
# Cant Find Class: com/mojang/brigadier/suggestion/SuggestionProvider
# Cant Find Class: com/mojang/brigadier/context/StringRange
# Cant Find Class: com/mojang/datafixers/util/Either
# Cant Find Class: org/apache/commons/lang3/mutable/MutableBoolean
# Cant Find Class: com/mojang/brigadier/exceptions/Dynamic2CommandExceptionType$Function
# Cant Find Class: com/mojang/brigadier/exceptions/Dynamic2CommandExceptionType
# Cant Find Class: com/google/common/primitives/Doubles
# Cant Find Class: com/mojang/brigadier/exceptions/Dynamic3CommandExceptionType$Function
# Cant Find Class: com/mojang/brigadier/exceptions/Dynamic3CommandExceptionType
# Cant Find Class: com/google/common/collect/UnmodifiableIterator
# Cant Find Class: com/mojang/brigadier/arguments/FloatArgumentType
# Cant Find Class: com/mojang/brigadier/arguments/LongArgumentType
# Cant Find Class: com/mojang/brigadier/arguments/StringArgumentType$StringType
# Cant Find Class: com/mojang/brigadier/arguments/DoubleArgumentType
# Cant Find Class: com/mojang/brigadier/tree/ArgumentCommandNode
# Cant Find Class: com/google/common/base/Strings
# Cant Find Class: com/google/common/collect/AbstractIterator
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2ObjectOpenHashMap
# Cant Find Class: com/mojang/serialization/codecs/RecordCodecBuilder$Instance
# Cant Find Class: com/mojang/serialization/codecs/RecordCodecBuilder
# Cant Find Class: com/mojang/datafixers/Products$P1
# Cant Find Class: com/mojang/datafixers/Products
# Cant Find Class: com/mojang/datafixers/kinds/App
# Cant Find Class: com/mojang/serialization/MapCodec
# Cant Find Class: com/mojang/datafixers/kinds/Applicative
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectMap
# Cant Find Class: com/mojang/datafixers/Products$P2
# Cant Find Class: com/mojang/serialization/codecs/PrimitiveCodec
# Cant Find Class: javax/annotation/concurrent/Immutable
# Cant Find Class: com/google/common/base/MoreObjects$ToStringHelper
# Cant Find Class: com/mojang/datafixers/Products$P3
# Cant Find Class: com/mojang/datafixers/util/Function3
# Cant Find Class: org/apache/commons/lang3/Validate
# Cant Find Class: com/mojang/serialization/Decoder
# Cant Find Class: com/google/common/collect/ImmutableMap$Builder
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectOpenHashMap
# Cant Find Class: org/jetbrains/annotations/Nullable
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongConsumer
# Cant Find Class: com/mojang/serialization/DataResult$PartialResult
# Cant Find Class: com/mojang/serialization/codecs/UnboundedMapCodec
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntOpenCustomHashMap
# Cant Find Class: com/google/common/base/Predicate
# Cant Find Class: com/mojang/serialization/Encoder
# Cant Find Class: com/mojang/serialization/Dynamic
# Cant Find Class: com/google/common/collect/ImmutableList$Builder
# Cant Find Class: com/google/common/collect/Sets$SetView
# Cant Find Class: com/google/common/base/Supplier
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectList
# Cant Find Class: com/google/common/base/Suppliers
# Cant Find Class: com/google/common/base/Function
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectMap
# Cant Find Class: org/jetbrains/annotations/NotNull
# Cant Find Class: oshi/hardware/CentralProcessor$ProcessorIdentifier
# Cant Find Class: oshi/hardware/CentralProcessor
# Cant Find Class: oshi/SystemInfo
# Cant Find Class: oshi/hardware/HardwareAbstractionLayer
# Cant Find Class: oshi/hardware/PhysicalMemory
# Found extra RuntimeVisibleParameterAnnotations entries in <init>(Ljava/lang/String;ILjava/lang/String;CILjava/lang/Integer;)V in net/minecraft/ChatFormatting: removing 2
# Found extra RuntimeVisibleParameterAnnotations entries in <init>(Ljava/lang/String;ILjava/lang/String;CZILjava/lang/Integer;)V in net/minecraft/ChatFormatting: removing 2
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectOpenHashMap
# Cant Find Class: oshi/hardware/VirtualMemory
# Cant Find Class: oshi/hardware/GlobalMemory
# Cant Find Class: oshi/hardware/GraphicsCard
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMap$Entry
# Cant Find Class: org/apache/commons/io/FileUtils
# Cant Find Class: com/google/gson/stream/JsonReader
# Cant Find Class: com/google/gson/internal/Streams
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMaps
# Cant Find Class: com/google/common/collect/ComparisonChain
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntList
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntArrayList
# Cant Find Class: com/google/common/collect/HashBasedTable
# Cant Find Class: com/google/common/collect/Table
# Cant Find Class: org/apache/commons/lang3/StringUtils
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2DoubleMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2DoubleArrayMap
# Cant Find Class: com/google/common/base/Objects
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectAVLTreeMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectSortedMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectCollection
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntAVLTreeSet
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntCollection
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntIterator
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2IntMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2IntOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntListIterator
# Cant Find Class: com/google/common/annotations/VisibleForTesting
# Cant Find Class: com/google/common/base/Predicates
# Found extra RuntimeVisibleParameterAnnotations entries in <init>(Lnet/minecraft/world/entity/animal/Fox;Ljava/lang/Class;ZZLjava/util/function/Predicate;)V in net/minecraft/world/entity/animal/Fox$DefendTrustedTargetGoal: removing 1
# Cant Find Class: org/apache/commons/lang3/tuple/Pair
# Cant Find Class: io/netty/channel/SimpleChannelInboundHandler
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntOpenHashSet
# Cant Find Class: org/apache/commons/lang3/mutable/MutableObject
# Cant Find Class: com/mojang/serialization/MapLike
# Cant Find Class: io/netty/util/internal/ThreadLocalRandom
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2ObjectArrayMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectArraySet
# Cant Find Class: com/mojang/serialization/RecordBuilder
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectOpenHashSet
# Cant Find Class: com/mojang/datafixers/Products$P4
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongSet
# Cant Find Class: com/mojang/datafixers/util/Function4
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongOpenHashSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ByteMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2ObjectMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ByteOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2ObjectOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2ObjectFunction
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongOpenHashMap
# Cant Find Class: com/mojang/serialization/OptionalDynamic
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectFunction
# Cant Find Class: com/mojang/serialization/DataResult$Instance
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntBinaryOperator
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntSet
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectListIterator
# Cant Find Class: com/mojang/serialization/DynamicLike
# Cant Find Class: com/google/common/primitives/UnsignedLong
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongIterator
# Cant Find Class: com/mojang/datafixers/Products$P8
# Cant Find Class: com/mojang/datafixers/util/Function8
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2BooleanMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2BooleanFunction
# Cant Find Class: com/mojang/datafixers/Products$P6
# Cant Find Class: com/mojang/datafixers/util/Function6
# Cant Find Class: com/google/common/collect/Queues
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectArrays
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2BooleanOpenHashMap
# Cant Find Class: com/mojang/datafixers/Products$P5
# Cant Find Class: com/mojang/datafixers/util/Function5
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongArrayList
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongList
# Cant Find Class: com/mojang/serialization/codecs/RecordCodecBuilder$Mu
# Cant Find Class: com/mojang/datafixers/Products$P7
# Cant Find Class: com/mojang/datafixers/util/Function7
# Cant Find Class: com/google/common/cache/CacheLoader
# Cant Find Class: com/google/common/cache/LoadingCache
# Cant Find Class: com/google/common/cache/CacheBuilder
# Cant Find Class: com/mojang/datafixers/Products$P13
# Cant Find Class: com/mojang/serialization/codecs/SimpleMapCodec
# Cant Find Class: com/mojang/datafixers/util/Function13
# Cant Find Class: com/mojang/datafixers/Products$P11
# Cant Find Class: com/mojang/datafixers/util/Function11
# Cant Find Class: com/mojang/datafixers/Products$P9
# Cant Find Class: com/mojang/datafixers/util/Function9
# Cant Find Class: com/mojang/datafixers/Products$P10
# Cant Find Class: com/mojang/datafixers/util/Function10
# Cant Find Class: it/unimi/dsi/fastutil/doubles/DoubleList
# Cant Find Class: it/unimi/dsi/fastutil/doubles/DoubleArrayList
# Cant Find Class: it/unimi/dsi/fastutil/doubles/DoubleListIterator
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntRBTreeSet
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntSortedSet
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntBidirectionalIterator
# Cant Find Class: it/unimi/dsi/fastutil/doubles/Double2DoubleFunction
# Cant Find Class: com/mojang/datafixers/Products$P15
# Cant Find Class: com/mojang/datafixers/util/Function15
# Cant Find Class: org/apache/commons/lang3/mutable/MutableDouble
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2IntMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2IntOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2IntFunction
# Cant Find Class: com/google/common/hash/HashFunction
# Cant Find Class: com/google/common/base/Charsets
# Cant Find Class: com/google/common/hash/HashCode
# Cant Find Class: com/google/common/primitives/Longs
# Cant Find Class: com/google/common/hash/Hashing
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectLinkedOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectMaps
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectIterable
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectMaps
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongSortedSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongAVLTreeSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongBidirectionalIterator
# Cant Find Class: com/google/common/io/Files
# Cant Find Class: com/google/common/io/ByteSource
# Cant Find Class: com/google/common/collect/HashMultimap
# Cant Find Class: com/google/common/collect/ImmutableMultimap
# Cant Find Class: com/google/common/collect/BiMap
# Cant Find Class: com/google/common/collect/HashBiMap
# Cant Find Class: com/google/gson/TypeAdapter
# Cant Find Class: com/google/gson/stream/JsonWriter
# Cant Find Class: org/slf4j/Marker
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongLinkedOpenHashSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongCollection
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongLinkedOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/HashCommon
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2ByteLinkedOpenHashMap
# Cant Find Class: com/google/common/base/Preconditions
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2BooleanMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2BooleanFunction
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2BooleanOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/floats/Float2FloatFunction
# Cant Find Class: com/google/common/collect/ImmutableSortedMap
# Cant Find Class: com/mojang/serialization/MapEncoder
# Cant Find Class: com/mojang/serialization/MapDecoder
# Cant Find Class: com/google/common/collect/ArrayTable
# ...
#   Patching net/minecraft/client/renderer/Sheets$1 1/1
#   Patching net/minecraft/client/resources/language/LanguageInfo 1/1
#   Patching net/minecraft/client/gui/screens/recipebook/RecipeBookPage 1/1
#   Patching net/minecraft/client/RecipeBookCategories$1 1/1
#   Patching net/minecraft/client/renderer/texture/TextureManager 1/1
#   Patching net/minecraft/client/gui/screens/inventory/AbstractContainerScreen 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$Cache 1/1
#   Patching net/minecraft/client/gui/screens/multiplayer/ServerSelectionList$OnlineServerEntry 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$BlendState 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat$Mode 1/1
#   Patching net/minecraft/client/renderer/texture/TextureAtlas$Preparations 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransforms$Deserializer 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$DestFactor 1/1
#   Patching net/minecraft/client/gui/components/AbstractSelectionList$Entry 1/1
#   Patching net/minecraft/client/renderer/ShaderInstance$1 1/1
#   Patching net/minecraft/client/renderer/blockentity/BlockEntityRenderers 1/1
#   Patching net/minecraft/client/resources/model/SimpleBakedModel$Builder 1/1
#   Patching net/minecraft/client/gui/screens/inventory/EnchantmentScreen 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionScreen$1 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/CreateWorldScreen$OperationFailedException 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer$RenderInfoMap 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsScreen 1/1
#   Patching net/minecraft/client/multiplayer/ServerData$ServerPackStatus 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$Entry 1/1
#   Patching net/minecraft/client/renderer/blockentity/PistonHeadRenderer 1/1
#   Patching net/minecraft/client/Minecraft$1 1/1
#   Patching net/minecraft/client/multiplayer/ClientLevel$1 1/1
#   Patching net/minecraft/client/gui/screens/multiplayer/ServerSelectionList$LANHeader 1/1
#   Patching net/minecraft/client/KeyMapping 1/1
#   Patching net/minecraft/client/gui/screens/ConnectScreen$1 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$3 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$4 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$SourceFactor 1/1
#   Patching net/minecraft/client/User 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen$SlotWrapper 1/1
#   Patching net/minecraft/client/resources/language/ClientLanguage 1/1
#   Patching net/minecraft/client/KeyboardHandler$1 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$Cache$1 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$Cache$2 1/1
#   Patching net/minecraft/client/gui/screens/multiplayer/ServerSelectionList$NetworkServerEntry 1/1
#   Patching net/minecraft/client/renderer/RenderType 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$CompiledChunk$1 1/1
#   Patching net/minecraft/client/renderer/entity/ItemEntityRenderer 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemModelGenerator$SpanFacing 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockModel$Deserializer 1/1
#   Patching net/minecraft/client/renderer/entity/EntityRenderer 1/1
#   Patching net/minecraft/client/multiplayer/ClientChunkCache$Storage 1/1
#   Patching net/minecraft/client/gui/components/DebugScreenOverlay 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$1 1/1
#   Patching net/minecraft/client/renderer/entity/LivingEntityRenderer$1 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$2 1/1
#   Patching net/minecraft/client/multiplayer/ServerStatusPinger$1 1/1
#   Patching net/minecraft/client/multiplayer/ClientLevel$EntityCallbacks 1/1
#   Patching net/minecraft/client/multiplayer/ServerStatusPinger$2 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldPreset 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer$RenderChunkInfo 1/1
#   Patching net/minecraft/client/server/IntegratedServer 1/1
#   Patching net/minecraft/client/resources/model/MultiPartBakedModel$Builder 1/1
#   Patching net/minecraft/client/renderer/FogRenderer 1/1
#   Patching net/minecraft/client/renderer/block/LiquidBlockRenderer$1 1/1
#   Patching net/minecraft/client/renderer/block/BlockRenderDispatcher 1/1
#   Patching net/minecraft/client/resources/model/ModelManager 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemModelGenerator$Span 1/1
#   Patching net/minecraft/client/renderer/ItemInHandRenderer 1/1
#   Patching net/minecraft/client/renderer/block/LiquidBlockRenderer 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle$SnowballProvider 1/1
#   Patching com/mojang/blaze3d/vertex/VertexMultiConsumer 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$ScissorState 1/1
#   Patching net/minecraft/client/renderer/entity/LivingEntityRenderer 1/1
#   Patching net/minecraft/client/multiplayer/ClientChunkCache 1/1
#   Patching net/minecraft/client/renderer/PostChain 1/1
#   Patching net/minecraft/client/renderer/Sheets 1/1
#   Patching net/minecraft/client/renderer/entity/player/PlayerRenderer 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat$IndexType 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockModel$LoopException 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$SizeInfo 1/1
#   Patching net/minecraft/client/renderer/RenderType$CompositeState$CompositeStateBuilder 1/1
#   Patching net/minecraft/client/renderer/ItemInHandRenderer$HandRenderSelection 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$TextureState 1/1
#   Patching net/minecraft/client/renderer/texture/TextureAtlasSprite$AnimatedTexture 1/1
#   Patching net/minecraft/client/ClientBrandRetriever 1/1
#   Patching net/minecraft/client/gui/MapRenderer$MapInstance 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemOverrides 1/1
#   Patching net/minecraft/client/gui/Gui$HeartType 1/1
#   Patching net/minecraft/client/renderer/entity/layers/ElytraLayer 1/1
#   Patching net/minecraft/client/gui/screens/Screen 1/1
#   Patching com/mojang/blaze3d/vertex/VertexMultiConsumer$Multiple 1/1
#   Patching net/minecraft/client/particle/TerrainParticle 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormatElement$Usage$ClearState 1/1
#   Patching com/mojang/blaze3d/vertex/BufferBuilder$DrawState 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$ColorMask 1/1
#   Patching com/mojang/blaze3d/platform/Window 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransform 1/1
#   Patching net/minecraft/client/gui/components/BossHealthOverlay 1/1
#   Patching net/minecraft/client/renderer/ItemModelShaper 1/1
#   Patching net/minecraft/client/player/RemotePlayer 1/1
#   Patching net/minecraft/client/main/Main 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$RenderChunk$ResortTransparencyTask 1/1
#   Patching net/minecraft/client/gui/screens/Screen$NarratableSearchResult 1/1
#   Patching net/minecraft/client/resources/model/BakedModel 1/1
#   Patching net/minecraft/world/level/biome/BiomeSpecialEffects$GrassColorModifier$ColorModifier 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsList 1/1
#   Patching net/minecraft/client/renderer/DimensionSpecialEffects$OverworldEffects 1/1
#   Patching net/minecraft/client/gui/screens/TitleScreen$1 1/1
#   Patching net/minecraft/client/gui/components/AbstractSelectionList$TrackedList 1/1
#   Patching net/minecraft/client/renderer/EffectInstance 1/1
#   Patching net/minecraft/client/renderer/SpriteCoordinateExpander 1/1
#   Patching net/minecraft/Util$3 1/1
#   Patching net/minecraft/client/multiplayer/ClientPacketListener 1/1
#   Patching net/minecraft/client/renderer/DimensionSpecialEffects$EndEffects 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementsScreen 1/1
#   Patching com/mojang/blaze3d/pipeline/RenderTarget 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldSelectionList$WorldListEntry 1/1
#   Patching net/minecraft/client/renderer/OutlineBufferSource 1/1
#   Patching net/minecraft/client/resources/model/ModelState 1/1
#   Patching net/minecraft/client/server/LanServerDetection$LanServerDetector 1/1
#   Patching net/minecraft/client/sounds/SoundEngine 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$DepthState 1/1
#   Patching net/minecraft/client/multiplayer/ServerData 1/1
#   Patching net/minecraft/client/renderer/texture/TextureAtlas 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemModelGenerator$1 1/1
#   Patching net/minecraft/client/renderer/ItemInHandRenderer$1 1/1
#   Patching net/minecraft/client/gui/screens/LoadingOverlay 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle$SlimeProvider 1/1
#   Patching net/minecraft/client/renderer/entity/ItemFrameRenderer 1/1
#   Patching net/minecraft/client/renderer/FogRenderer$FogMode 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldSelectionList 1/1
#   Patching net/minecraft/client/gui/screens/inventory/LoomScreen 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$Viewport 1/1
#   Patching net/minecraft/client/renderer/item/ItemProperties$CompassWobble 1/1
#   Patching net/minecraft/client/resources/model/WeightedBakedModel 1/1
#   Patching net/minecraft/client/renderer/ShaderInstance 1/1
#   Patching net/minecraft/client/Minecraft 1/1
#   Patching net/minecraft/client/ToggleKeyMapping 1/1
#   Patching net/minecraft/client/renderer/RenderType$CompositeRenderType 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$ChunkTaskResult 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransforms$1 1/1
#   Patching net/minecraft/client/gui/screens/ConnectScreen 1/1
#   Patching net/minecraft/client/renderer/blockentity/SkullBlockRenderer 1/1
#   Patching net/minecraft/client/server/LanServerDetection$LanServerList 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$AmbientVertexRemap 1/1
#   Patching net/minecraft/client/particle/ParticleEngine 1/1
#   Patching net/minecraft/client/gui/screens/DeathScreen 1/1
#   Patching net/minecraft/client/renderer/block/model/BakedQuad 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$ColorLogicState 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementTabType 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$EntryBase 1/1
#   Patching net/minecraft/client/renderer/entity/EntityRenderDispatcher 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemOverrides$PropertyMatcher 1/1
#   Patching net/minecraft/world/item/Items$1 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle$Provider 1/1
#   Patching net/minecraft/client/gui/components/DebugScreenOverlay$1 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockModel$GuiLight 1/1
#   Patching net/minecraft/client/gui/screens/inventory/tooltip/ClientTooltipComponent 1/1
#   Patching net/minecraft/client/renderer/texture/Stitcher$Holder 1/1
#   Patching net/minecraft/client/Screenshot 1/1
#   Patching com/mojang/blaze3d/vertex/SheetedDecalTextureGenerator 1/1
#   Patching net/minecraft/client/User$Type 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldPreset$PresetEditor 1/1
#   Patching com/mojang/blaze3d/vertex/BufferBuilder 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldGenSettingsComponent 1/1
#   Patching com/mojang/realmsclient/gui/screens/RealmsGenericErrorScreen 1/1
#   Patching net/minecraft/client/gui/screens/OptionsScreen 1/1
#   Patching net/minecraft/client/RecipeBookCategories 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat$1 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransforms$TransformType 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer$RenderChunkStorage 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$UnselectedPackEntry 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$1 1/1
#   Patching net/minecraft/client/renderer/block/model/FaceBakery 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$LogicOp 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen 1/1
#   Patching net/minecraft/client/resources/language/I18n 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementTabType$1 1/1
#   Patching net/minecraft/client/gui/components/AbstractWidget 1/1
#   Patching net/minecraft/client/renderer/DimensionSpecialEffects$SkyType 1/1
#   Patching net/minecraft/client/gui/screens/LoadingOverlay$LogoTexture 1/1
#   Patching net/minecraft/client/gui/screens/multiplayer/JoinMultiplayerScreen 1/1
#   Patching net/minecraft/client/renderer/block/BlockRenderDispatcher$1 1/1
#   Patching net/minecraft/client/particle/ParticleEngine$SpriteParticleRegistration 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsList$CategoryEntry 1/1
#   Patching net/minecraft/client/player/AbstractClientPlayer 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementTab 1/1
#   Patching net/minecraft/client/KeyboardHandler 1/1
#   Patching net/minecraft/client/renderer/entity/BoatRenderer 1/1
#   Patching net/minecraft/client/gui/screens/MenuScreens$ScreenConstructor 1/1
#   Patching net/minecraft/client/multiplayer/ClientLevel$ClientLevelData 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$RenderChunk$ChunkCompileTask 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen$CustomCreativeSlot 1/1
#   Patching net/minecraft/client/multiplayer/ServerStatusPinger$2$1 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormatElement$Usage 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$AmbientOcclusionFace 1/1
#   Patching net/minecraft/client/multiplayer/ClientHandshakePacketListenerImpl 1/1
#   Patching net/minecraft/client/multiplayer/ClientPacketListener$1 1/1
#   Patching net/minecraft/client/particle/ParticleEngine$MutableSpriteSet 1/1
#   Patching net/minecraft/client/color/item/ItemColors 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsList$CategoryEntry$1 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransform$Deserializer 1/1
#   Patching com/mojang/blaze3d/vertex/BufferBuilder$SortState 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$SelectedPackEntry 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$RenderChunk$RebuildTask 1/1
#   Patching net/minecraft/client/renderer/texture/MipmapGenerator 1/1
#   Patching net/minecraft/client/renderer/ScreenEffectRenderer 1/1
#   Patching net/minecraft/client/gui/screens/MenuScreens 1/1
#   Patching net/minecraft/client/gui/screens/TitleScreen 1/1
#   Patching net/minecraft/client/main/Main$2 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/CreateWorldScreen$SelectedGameMode 1/1
#   Patching net/minecraft/client/main/Main$1 1/1
#   Patching net/minecraft/client/server/LanServerPinger 1/1
#   Patching net/minecraft/client/main/Main$3 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle 1/1
#   Patching net/minecraft/client/gui/screens/TitleScreen$Warning32Bit 1/1
#   Patching net/minecraft/client/resources/model/SimpleBakedModel 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager 1/1
#   Patching net/minecraft/client/multiplayer/MultiPlayerGameMode 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen$ItemPickerMenu 1/1
#   Patching net/minecraft/client/renderer/entity/ItemRenderer 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormatElement$Usage$SetupState 1/1
# The server installed successfully
# You can delete this installer file now if you wish
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2dpcrBOra0EQVqc7MkOH0XV633N_4bR68rWDhARKT1zT7GRHj" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      libraries		user_jvm_args.txt
# banned-players.json  logs		usercache.json
# colabconfig.json     mods		usernamecache.json
# config		     ops.json		whitelist.json
# crash-reports	     patchouli_books	world
# defaultconfigs	     run.bat		xaerominimap-common.txt
# eula.txt	     run.sh		xaeroworldmap-common.txt
# forge.jar	     server.properties
# forge.jar.log	     structurize
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 4.tcp.ngrok.io:15533
# Estas jugando a minecraft: forge en su version: 1.18.2
# La versión de Forge es: 1.18.2-40.2.17
# /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/1.18.2-40.2.17/unix_args.txt
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [20:53:53] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 40.2.17, --fml.mcVersion, 1.18.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220404.173914]
# [20:53:53] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 9.1.3+9.1.3+main.9b69c82a starting: java version 21.0.2 by Microsoft
# [20:53:53] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2314!/ Service=ModLauncher Env=SERVER
# [20:53:54] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.18.2-40.2.17/fmlcore-1.18.2-40.2.17.jar is missing mods.toml file
# [20:53:54] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.18.2-40.2.17/javafmllanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [20:53:54] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.18.2-40.2.17/lowcodelanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [20:53:54] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.18.2-40.2.17/mclanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [20:53:54] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 4 dependencies adding them to mods collection
# [20:53:58] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [20:53:58] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [tictim.paraglider.MixinConnector]
# [20:53:58] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# [20:53:58] [main/WARN] [mixin/]: Reference map 'simplyswords-common-refmap.json' for simplyswords-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [20:53:58] [main/WARN] [mixin/]: Reference map 'simplyswords-forge-refmap.json' for simplyswords.mixins.json could not be read. If this is a development environment you can ignore this message
# [20:53:58] [main/WARN] [mixin/]: Reference map 'cristellib-common-refmap.json' for cristellib-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [20:53:58] [main/WARN] [mixin/]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [20:53:59] [main/INFO] [terralith/]: No config file detected. Creating one...
# [20:53:59] [main/INFO] [terralith/]: Loading config for 'terrablender_compatibility': TRUE
# [20:53:59] [main/INFO] [terralith/]: No config file detected. Creating one...
# [20:53:59] [main/INFO] [terralith/]: Loading config for 'cursed_skylands': NONE
# [20:53:59] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/player/AbstractClientPlayer for invalid dist DEDICATED_SERVER
# [20:53:59] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/player/AbstractClientPlayer (java.lang.RuntimeException: Attempted to load class net/minecraft/client/player/AbstractClientPlayer for invalid dist DEDICATED_SERVER)
# [20:53:59] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.player.AbstractClientPlayer was not found mixins.irons_spellbooks.json:AbstractClientPlayerMixin
# [20:53:59] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/gui/Gui for invalid dist DEDICATED_SERVER
# [20:53:59] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/Gui (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/Gui for invalid dist DEDICATED_SERVER)
# [20:53:59] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.Gui was not found mixins.irons_spellbooks.json:GuiMixin
# [20:53:59] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/renderer/entity/ItemRenderer for invalid dist DEDICATED_SERVER
# [20:53:59] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/entity/ItemRenderer (java.lang.RuntimeException: Attempted to load class net/minecraft/client/renderer/entity/ItemRenderer for invalid dist DEDICATED_SERVER)
# [20:53:59] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.renderer.entity.ItemRenderer was not found mixins.irons_spellbooks.json:ItemRendererMixin
# [20:53:59] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/player/LocalPlayer for invalid dist DEDICATED_SERVER
# [20:53:59] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/player/LocalPlayer (java.lang.RuntimeException: Attempted to load class net/minecraft/client/player/LocalPlayer for invalid dist DEDICATED_SERVER)
# [20:53:59] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.player.LocalPlayer was not found mixins.irons_spellbooks.json:LocalPlayerMixin
# [20:53:59] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/particle/Particle for invalid dist DEDICATED_SERVER
# [20:53:59] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/particle/Particle (java.lang.RuntimeException: Attempted to load class net/minecraft/client/particle/Particle for invalid dist DEDICATED_SERVER)
# [20:53:59] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.particle.Particle was not found mixins.irons_spellbooks.json:ParticleMixin
# [20:53:59] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/entity/layers/SpinAttackEffectLayer (java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.layers.SpinAttackEffectLayer)
# [20:53:59] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.renderer.entity.layers.SpinAttackEffectLayer was not found mixins.irons_spellbooks.json:SpinAttackEffectLayerMixin
# [20:54:03] [main/WARN] [mixin/]: @Final field f_31427_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [20:54:03] [main/WARN] [mixin/]: @Final field f_31428_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [20:54:09] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for illagerinvasion:main
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ender_step
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ender_obscuris
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:dodge_master
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:precise_roll
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:shadow_step
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:bull_charge
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:demon_mark_passive
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:torment_passive
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ruine_passive
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:lunar_echo_passive
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:satsujin_passive
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:solar_passive
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:charybdis
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:agony_plunge
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:true_berserk
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:plunder_perdition
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:sakura_state
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ender_blast
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ender_fusion
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:demonic_ascension
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:regierung
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:lunar_eclipse
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:solar_arcano
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:counter_attack
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:perfect_bulwark
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:vengeful_parry
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:arrow_tenacity
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:pain_anticipation
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:latent_retribution
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:vampirize
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:critical_knowledge
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:heart_shield
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:mindset
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:adrenaline
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:dancing_blade
# [20:54:09] [modloading-worker-0/INFO] [epicfight/]: register skill wom:meditation
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:basic_attack
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:air_attack
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:roll
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:step
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:knockdown_wakeup
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:guard
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:parrying
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:impact_guard
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:berserker
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:death_harvest
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:emergency_escape
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:endurance
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:forbidden_strength
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:hypervitality
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:stamina_pillager
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:swordmaster
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:technician
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:sweeping_edge
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:dancing_edge
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:the_guillotine
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:grasping_spire
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:heartpiercer
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:steel_whirlwind
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:battojutsu
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:battojutsu_passive
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:rushing_tempo
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:relentless_combo
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:liechtenauer
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:sharp_stab
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:eviscerate
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:blade_rush
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:wrathful_lighting
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:tsunami
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:everlasting_allegiance
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:meteor_slam
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:revelation
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:demolition_leap
# [20:54:10] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:phantom_ascent
# [20:54:10] [modloading-worker-0/INFO] [terralith/]: Terrablender detected
# [20:54:10] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 40.2.17, for MC 1.18.2 with MCP 20220404.173914
# [20:54:10] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v40.2.17 Initialized
# [20:54:12] [modloading-worker-0/INFO] [TrustedSourceList/]: Loading BlackListed sources from remote... (https://api.stopmodreposts.org/minecraft/sites.txt)
# [20:54:12] [modloading-worker-0/INFO] [twilightforest/]: Skipped compatibility for mod tconstruct.
# [20:54:12] [modloading-worker-0/INFO] [twilightforest/]: Skipped compatibility for mod undergarden.
# [20:54:12] [modloading-worker-0/INFO] [twilightforest/]: Skipped compatibility for mod immersiveengineering.
# [20:54:12] [modloading-worker-0/INFO] [twilightforest/]: Loaded compatibility for mod Curios.
# [20:54:13] [modloading-worker-0/INFO] [ir.IronFurnaces/]: Initializing Update Checker...
# [20:54:13] [ Iron Furnaces Update Checker/INFO] [ir.IronFurnaces/]: Starting Update Check...
# [20:54:13] [ Iron Furnaces Update Checker/INFO] [ir.IronFurnaces/]: Update Check done!
# [20:54:13] [ Iron Furnaces Update Checker/INFO] [ir.IronFurnaces/]: Iron Furnaces is up to date!
# [20:54:13] [modloading-worker-0/INFO] [TrustedSourceList/]: Loaded 564 BlackListed sources from remote
# [20:54:13] [modloading-worker-0/INFO] [TrustManager/]: Loading mod 'commonality' TrustWorthiness...
# [20:54:13] [modloading-worker-0/FATAL] [TrustManager/]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [20:54:13] [modloading-worker-0/INFO] [TrustManager/]: Loaded mod 'commonality' TrustWorthiness: UNKNOWN
# [20:54:15] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id architectury:sync_ids
# [20:54:15] [modloading-worker-0/INFO] [TrustManager/]: Loading mod 'apexcore' TrustWorthiness...
# [20:54:15] [modloading-worker-0/FATAL] [TrustManager/]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [20:54:15] [modloading-worker-0/INFO] [TrustManager/]: Loaded mod 'apexcore' TrustWorthiness: UNKNOWN
# [20:54:16] [modloading-worker-0/INFO] [co.tt.re.AbstractRegistrate/]: Detected new forge version, registering events reflectively.
# [20:54:16] [modloading-worker-0/INFO] [TrustManager/]: Loading mod 'fantasyfurniture' TrustWorthiness...
# [20:54:16] [modloading-worker-0/FATAL] [TrustManager/]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [20:54:16] [modloading-worker-0/INFO] [TrustManager/]: Loaded mod 'fantasyfurniture' TrustWorthiness: UNKNOWN
# [20:54:16] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for puzzleslib:main
# /workspaces/codespaces-jupyter/Minecraft-server/config
# [20:54:16] [modloading-worker-0/INFO] [co.tt.re.AbstractRegistrate/]: Detected new forge version, registering events reflectively.
# [20:54:16] [modloading-worker-0/INFO] [Cristel Lib/]: dumping Runtime Pack's assets and data
# [20:54:21] [modloading-worker-0/INFO] [co.sk.we.WeaponMaster/]: Total varients loaded: 1509035
# [20:54:25] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `domum_ornamentum` for name `architects_cutter`, expected `minecolonies`. This could be a intended override, but in most cases indicates a broken mod.
# [20:54:28] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityLeafcutterAnt from class com.github.alexthe666.alexsmobs.entity.EntityDevilsHolePupfish
# [20:54:28] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityMantisShrimp from class com.github.alexthe666.alexsmobs.entity.EntitySkelewag
# [20:54:29] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [illagerinvasion] Starting version check at https://raw.githubusercontent.com/Fuzss/modresources/main/update/illagerinvasion.json
# [20:54:29] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [illagerinvasion] Found status: UP_TO_DATE Current: 3.0.5 Target: null
# [20:54:29] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [goblintraders] Starting version check at https://mrcrayfish.com/modupdatejson?id=goblintraders
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [goblintraders] Found status: BETA Current: 1.8.0 Target: 1.8.0
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [additionalstructures] Starting version check at https://raw.githubusercontent.com/XxRexRaptorxX/Update-Checker/main/AdditionalStructures.json
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [additionalstructures] Found status: AHEAD Current: 3.1.1 Target: null
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [forge] Starting version check at https://files.minecraftforge.net/net/minecraftforge/forge/promotions_slim.json
# [20:54:30] [modloading-worker-0/INFO] [co.sk.wo.ex.pl.PlatformManager/]: Got request to register class com.sk89q.worldedit.forge.ForgePlatform with WorldEdit [com.sk89q.worldedit.extension.platform.PlatformManager@37a9c78]
# [20:54:30] [modloading-worker-0/INFO] [co.sk.wo.fo.ForgeWorldEdit/]: WorldEdit for Forge (version 7.2.10+1742f98) is loaded
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [forge] Found status: OUTDATED Current: 40.2.17 Target: 40.2.18
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [twilightforest] Starting version check at https://gh.tamaized.com/TeamTwilight/twilightforest/update.json
# [20:54:30] [main/INFO] [terralith/]: Terrablender compatibility enabled
# [20:54:30] [main/INFO] [terrablender/]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [20:54:30] [main/INFO] [terrablender/]: Registered region minecraft:nether to index 0 for type NETHER
# [20:54:30] [main/INFO] [terrablender/]: Registered region terralith:overworld to index 1 for type OVERWORLD
# [20:54:30] [Forge Version Check/WARN] [ne.mi.fm.VersionChecker/]: Failed to process update information
# com.google.gson.JsonSyntaxException: java.lang.IllegalStateException: Expected BEGIN_OBJECT but was STRING at line 1 column 1 path $
# 	at com.google.gson.Gson.fromJson(Gson.java:975) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.Gson.fromJson(Gson.java:928) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.Gson.fromJson(Gson.java:877) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.Gson.fromJson(Gson.java:848) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at net.minecraftforge.fml.VersionChecker$1.process(VersionChecker.java:183) ~[fmlcore-1.18.2-40.2.17.jar%23113!/:?] {}
# 	at java.lang.Iterable.forEach(Iterable.java:75) [?:?] {re:mixin}
# 	at net.minecraftforge.fml.VersionChecker$1.run(VersionChecker.java:114) [fmlcore-1.18.2-40.2.17.jar%23113!/:?] {}
# Caused by: java.lang.IllegalStateException: Expected BEGIN_OBJECT but was STRING at line 1 column 1 path $
# 	at com.google.gson.stream.JsonReader.beginObject(JsonReader.java:384) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.internal.bind.MapTypeAdapterFactory$Adapter.read(MapTypeAdapterFactory.java:183) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.internal.bind.MapTypeAdapterFactory$Adapter.read(MapTypeAdapterFactory.java:145) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.Gson.fromJson(Gson.java:963) ~[gson-2.8.9.jar%2321!/:?] {}
# 	... 6 more
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [commonality] Starting version check at https://raw.githubusercontent.com/ApexStudios-Dev/Version/master/commonality.json
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [commonality] Found status: AHEAD Current: 1.4.0 Target: null
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [days_in_the_middle_ages] Starting version check at https://raw.githubusercontent.com/PlayTics/playtics.github.io/main/update.json
# [20:54:30] [Forge Version Check/WARN] [ne.mi.fm.VersionChecker/]: Failed to process update information
# com.google.gson.JsonSyntaxException: java.lang.IllegalStateException: Expected BEGIN_OBJECT but was NUMBER at line 1 column 4 path $
# 	at com.google.gson.Gson.fromJson(Gson.java:975) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.Gson.fromJson(Gson.java:928) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.Gson.fromJson(Gson.java:877) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.Gson.fromJson(Gson.java:848) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at net.minecraftforge.fml.VersionChecker$1.process(VersionChecker.java:183) ~[fmlcore-1.18.2-40.2.17.jar%23113!/:?] {}
# 	at java.lang.Iterable.forEach(Iterable.java:75) [?:?] {re:mixin}
# 	at net.minecraftforge.fml.VersionChecker$1.run(VersionChecker.java:114) [fmlcore-1.18.2-40.2.17.jar%23113!/:?] {}
# Caused by: java.lang.IllegalStateException: Expected BEGIN_OBJECT but was NUMBER at line 1 column 4 path $
# 	at com.google.gson.stream.JsonReader.beginObject(JsonReader.java:384) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.internal.bind.MapTypeAdapterFactory$Adapter.read(MapTypeAdapterFactory.java:183) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.internal.bind.MapTypeAdapterFactory$Adapter.read(MapTypeAdapterFactory.java:145) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.Gson.fromJson(Gson.java:963) ~[gson-2.8.9.jar%2321!/:?] {}
# 	... 6 more
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [tombstone] Starting version check at https://raw.githubusercontent.com/Corail31/tombstone_lite/master/update.json
# [20:54:30] [main/INFO] [terrablender/]: Registered region biomesoplenty:overworld_common to index 2 for type OVERWORLD
# [20:54:30] [main/INFO] [terrablender/]: Registered region biomesoplenty:overworld_rare to index 3 for type OVERWORLD
# [20:54:30] [main/INFO] [terrablender/]: Registered region biomesoplenty:nether_common to index 1 for type NETHER
# [20:54:30] [main/INFO] [terrablender/]: Registered region biomesoplenty:nether_rare to index 2 for type NETHER
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [tombstone] Found status: UP_TO_DATE Current: 7.6.7 Target: null
# [20:54:30] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [apexcore] Starting version check at https://raw.githubusercontent.com/ApexStudios-Dev/Version/master/apexcore.json
# [20:54:31] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [apexcore] Found status: AHEAD Current: 4.13.0 Target: null
# [20:54:31] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [fantasyfurniture] Starting version check at https://api.modrinth.com/updates/fantasy-furniture/forge_updates.json
# [20:54:31] [modloading-worker-0/INFO] [xa.ma.se.WorldMapServer/]: Loading Xaero's World Map - Stage 1/2 (Server)
# [20:54:31] [modloading-worker-0/INFO] [xa.co.MinimapLogs/]: Loading Xaero's Minimap - Stage 1/2 (Server)
# [20:54:31] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [fantasyfurniture] Found status: UP_TO_DATE Current: 3.14.0 Target: null
# [20:54:31] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [puzzleslib] Starting version check at https://raw.githubusercontent.com/Fuzss/modresources/main/update/puzzleslib.json
# [20:54:31] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [puzzleslib] Found status: UP_TO_DATE Current: 3.5.9 Target: null
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Sheath_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Sheath_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/agony_walk
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/agony_walk
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Sheath_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_idle
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_idle
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_idle
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_walk
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_walk
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_run
# [20:54:31] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_run
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/herrscher_guard
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/herrscher_guard
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_hit
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_hit
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_parry
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_parry
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [20:54:32] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [20:54:32] [main/INFO] [xa.co.MinimapLogs/]: Loading Xaero's Minimap - Stage 2/2 (Server)
# [20:54:32] [main/INFO] [xa.ma.se.WorldMapServer/]: Loading Xaero's World Map - Stage 2/2 (Server)
# [20:54:32] [modloading-worker-0/INFO] [io.re.ir.IronsSpellbooks/]: Got IMC []
# [20:54:32] [modloading-worker-0/ERROR] [WTHIT/]: [WTHIT] Error creating instance of plugin null
# java.lang.NoClassDefFoundError: mcp/mobius/waila/api/ui/IElement
# 	at java.lang.Class.forName0(Native Method) ~[?:?] {re:mixin}
# 	at java.lang.Class.forName(Class.java:421) ~[?:?] {re:mixin}
# 	at java.lang.Class.forName(Class.java:412) ~[?:?] {re:mixin}
# 	at mcp.mobius.waila.plugin.PluginInfo.register(PluginInfo.java:42) ~[wthit-forge-4.13.6.jar%23108!/:4.13.6] {re:classloading}
# 	at mcp.mobius.waila.forge.ForgePluginLoader.gatherPlugins(ForgePluginLoader.java:42) ~[wthit-forge-4.13.6.jar%23108!/:4.13.6] {re:classloading}
# 	at mcp.mobius.waila.plugin.PluginLoader.loadPlugins(PluginLoader.java:18) ~[wthit-forge-4.13.6.jar%23108!/:4.13.6] {re:classloading}
# 	at mcp.mobius.waila.forge.ForgeWaila.loadComplete(ForgeWaila.java:41) ~[wthit-forge-4.13.6.jar%23108!/:4.13.6] {re:classloading,pl:eventbus:A}
# 	at net.minecraftforge.eventbus.ASMEventHandler_595_ForgeWaila_loadComplete_FMLLoadCompleteEvent.invoke(.dynamic) ~[?:?] {}
# 	at net.minecraftforge.eventbus.ASMEventHandler.invoke(ASMEventHandler.java:85) ~[eventbus-5.0.3.jar%232!/:?] {}
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:302) ~[eventbus-5.0.3.jar%232!/:?] {}
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:283) ~[eventbus-5.0.3.jar%232!/:?] {}
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.acceptEvent(FMLModContainer.java:106) ~[javafmllanguage-1.18.2-40.2.17.jar%23114!/:?] {}
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$4(ModContainer.java:123) ~[fmlcore-1.18.2-40.2.17.jar%23113!/:?] {}
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?] {}
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?] {}
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?] {}
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?] {}
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?] {}
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?] {}
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?] {}
# Caused by: java.lang.ClassNotFoundException: mcp.mobius.waila.api.ui.IElement
# 	at jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[?:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:137) ~[securejarhandler-1.0.8.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:137) ~[securejarhandler-1.0.8.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	... 20 more
# [20:54:32] [modloading-worker-0/INFO] [WTHIT/]: [WTHIT] Registering plugin minecraft:waystones at net.blay09.mods.waystones.compat.WailaProvider
# [20:54:32] [modloading-worker-0/INFO] [WTHIT/]: [WTHIT] Registering plugin waila:core at mcp.mobius.waila.forge.ForgePlugins.Core
# [20:54:32] [modloading-worker-0/WARN] [minecolonies/]: Register mappings
# [20:54:32] [modloading-worker-0/INFO] [WTHIT/]: [WTHIT] Registering plugin waila:vanilla at mcp.mobius.waila.forge.ForgePlugins.Vanilla
# [20:54:32] [modloading-worker-0/INFO] [WTHIT/]: [WTHIT] Plugin config reloaded
# [20:54:44] [main/INFO] [mojang/YggdrasilAuthenticationService]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [20:54:52] [main/WARN] [minecraft/VanillaPackResources]: Assets URL 'union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23112!/assets/.mcassetsroot' uses unexpected schema
# [20:54:52] [main/WARN] [minecraft/VanillaPackResources]: Assets URL 'union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23112!/data/.mcassetsroot' uses unexpected schema
# [20:55:02] [main/INFO] [co.sk.wo.ex.pl.PlatformCommandManager/]: Registering commands with com.sk89q.worldedit.forge.ForgePlatform
# [20:55:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, location] and [teleport, destination] with inputs: [0.1 -0.5 .9, 0 0 0]
# [20:55:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, location] and [teleport, targets] with inputs: [0.1 -0.5 .9, 0 0 0]
# [20:55:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, destination] and [teleport, targets] with inputs: [Player, 0123, @e, dd12be42-52a9-4a91-a8a1-11c01849e498]
# [20:55:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, targets] and [teleport, destination] with inputs: [Player, 0123, dd12be42-52a9-4a91-a8a1-11c01849e498]
# [20:55:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [teleport, targets, location] and [teleport, targets, destination] with inputs: [0.1 -0.5 .9, 0 0 0]
# [20:55:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [ma, maxWellDepth] and [ma, campfire] with inputs: [0, -1, -.5, 1.2, .5, -1234.56]
# [20:55:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [relics, ability, points, set, ability, points] and [relics, ability, points, set, ability, stat] with inputs: [0, -123, 123]
# [20:55:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [relics, ability, randomize, all] and [relics, ability, randomize, ability] with inputs: [all]
# [20:55:02] [main/WARN] [minecraft/Commands]: Ambiguity between arguments [structurize, scan, pos1, pos2, anchor_pos] and [structurize, scan, pos1, pos2, player] with inputs: [^1 ^ ^-5, 0 0 0, ~ ~ ~, ^ ^ ^, ~0.5 ~1 ~-5]
# [20:55:06] [Worker-Main-6/ERROR] [minecraft/TagLoader]: Couldn't load tag enemyexpansion:freeze_prevention_knockback as it is missing following references: enemyexpansion:marksman (from ee18.jar)
# [20:55:06] [Worker-Main-6/ERROR] [minecraft/TagLoader]: Couldn't load tag enemyexpansion:healable_undead as it is missing following references: enemyexpansion:marksman (from ee18.jar)
# [20:55:06] [Worker-Main-4/ERROR] [minecraft/TagLoader]: Couldn't load tag days_in_the_middle_ages:arrow_slit_top as it is missing following references: mma:arrow_slit_top (from Forge 1.18.2 Minecraft Middle Ages 0.0.4.jar),
# 	mma:arrowslittopmossy (from Forge 1.18.2 Minecraft Middle Ages 0.0.4.jar)
# [20:55:06] [Worker-Main-4/ERROR] [minecraft/TagLoader]: Couldn't load tag days_in_the_middle_ages:arrow_slit_bottom as it is missing following references: mma:arrowslitbottommossy (from Forge 1.18.2 Minecraft Middle Ages 0.0.4.jar),
# 	mma:arrow_slit_bottom (from Forge 1.18.2 Minecraft Middle Ages 0.0.4.jar)
# [20:55:06] [Worker-Main-4/ERROR] [minecraft/TagLoader]: Couldn't load tag days_in_the_middle_ages:arrow_slit as it is missing following references: mma:arrow_slit_mossy (from Forge 1.18.2 Minecraft Middle Ages 0.0.4.jar),
# 	mma:arrow_slit (from Forge 1.18.2 Minecraft Middle Ages 0.0.4.jar)
# [20:55:06] [Worker-Main-4/ERROR] [minecraft/TagLoader]: Couldn't load tag days_in_the_middle_ages:arrow_slit_middle as it is missing following references: mma:arrow_slit_middle (from Forge 1.18.2 Minecraft Middle Ages 0.0.4.jar),
# 	mma:arrowslitmiddlemossy (from Forge 1.18.2 Minecraft Middle Ages 0.0.4.jar)
# t=2024-03-17T20:55:08+0000 lvl=warn msg="failed to open private leg" id=279e456d2005 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-17T20:55:08+0000 lvl=warn msg="failed to open private leg" id=fbc8a9127a70 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-17T20:55:08+0000 lvl=warn msg="failed to open private leg" id=6cebbb37c31b typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-17T20:55:08+0000 lvl=warn msg="failed to open private leg" id=001c30336e77 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [20:55:21] [Worker-Main-5/ERROR] [minecraft/RecipeManager]: Parsing error loading recipe cozy_home:table_stump_cherry_recipe
# com.google.gson.JsonSyntaxException: Invalid item: minecraft:air
# ...
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [22:51:58] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Pd4vIn to Sonmipo]
# [22:52:09] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo was slain by Vindicator
# [22:52:09] [Server thread/INFO] [tombstone/]: The player Sonmipo has successfully been saved
# [22:53:18] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo has made the advancement [Cover Me with Diamonds]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [22:55:36] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo was slain by Vex
# [22:55:36] [Server thread/INFO] [tombstone/]: The player Sonmipo has successfully been saved
# [22:55:36] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: Sonmipo moved wrongly!
# [22:55:39] [Server thread/INFO] [minecraft/Villager]: Villager Villager['Cleric'/20633, l='ServerLevel[world]', x=1369.30, y=82.00, z=-191.60] died, message: 'Cleric was slain by Zombie'
# [22:55:46] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Sonmipo to Pd4vIn]
# [22:55:51] [Server thread/INFO] [minecraft/DedicatedServer]: Pd4vIn was killed by Evoker using magic
# [22:55:51] [Server thread/INFO] [tombstone/]: The player Pd4vIn has successfully been saved
# [22:55:54] [Netty Epoll Server IO #6/ERROR] [minecraft/ArgumentTypes]: Could not serialize com.sky.weaponmaster.commands.SwapPartCommand$PositionAregument@3a25340a (class com.sky.weaponmaster.commands.SwapPartCommand$PositionAregument) - will not be sent to client!
# [22:55:54] [Netty Epoll Server IO #6/ERROR] [minecraft/ArgumentTypes]: Could not serialize com.sky.weaponmaster.commands.SetAbilityCommand$AbilityAregument@583e30f1 (class com.sky.weaponmaster.commands.SetAbilityCommand$AbilityAregument) - will not be sent to client!
# [22:55:54] [Netty Epoll Server IO #6/ERROR] [minecraft/ArgumentTypes]: Could not serialize com.sky.weaponmaster.commands.SwapPartCommand$PartAregument@708c4759 (class com.sky.weaponmaster.commands.SwapPartCommand$PartAregument) - will not be sent to client!
# > [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [22:55:57] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Pd4vIn to Sonmipo]
# [22:56:12] [Server thread/INFO] [minecraft/DedicatedServer]: Pd4vIn has completed the challenge [Grimoire of Evokation]
# [22:56:38] [Server thread/INFO] [minecraft/DedicatedServer]: Pd4vIn was slain by Vex
# [22:56:38] [Server thread/INFO] [tombstone/]: The player Pd4vIn has successfully been saved
# [22:56:41] [Netty Epoll Server IO #6/ERROR] [minecraft/ArgumentTypes]: Could not serialize com.sky.weaponmaster.commands.SwapPartCommand$PositionAregument@3a25340a (class com.sky.weaponmaster.commands.SwapPartCommand$PositionAregument) - will not be sent to client!
# [22:56:41] [Netty Epoll Server IO #6/ERROR] [minecraft/ArgumentTypes]: Could not serialize com.sky.weaponmaster.commands.SetAbilityCommand$AbilityAregument@583e30f1 (class com.sky.weaponmaster.commands.SetAbilityCommand$AbilityAregument) - will not be sent to client!
# [22:56:41] [Netty Epoll Server IO #6/ERROR] [minecraft/ArgumentTypes]: Could not serialize com.sky.weaponmaster.commands.SwapPartCommand$PartAregument@708c4759 (class com.sky.weaponmaster.commands.SwapPartCommand$PartAregument) - will not be sent to client!
# > [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [22:56:43] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Pd4vIn to Sonmipo]
# [22:57:03] [Server thread/WARN] [minecraft/ServerGamePacketListenerImpl]: Pd4vIn moved wrongly!
# [23:03:49] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo was slain by Vex
# [23:03:49] [Server thread/INFO] [tombstone/]: The player Sonmipo has successfully been saved
# [23:03:52] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Sonmipo to Pd4vIn]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [23:04:19] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo was slain by Vindicator
# [23:04:21] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Sonmipo to Pd4vIn]
# [23:04:26] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo was slain by Vex
# [23:04:26] [Server thread/INFO] [tombstone/]: The player Sonmipo has successfully been saved
# [23:04:32] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Sonmipo to Pd4vIn]
# [23:04:58] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo was slain by Vindicator
# [23:04:58] [Server thread/INFO] [tombstone/]: The player Sonmipo has successfully been saved
# [23:05:08] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Sonmipo to Pd4vIn]
# [23:06:36] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo was slain by Vindicator
# [23:06:36] [Server thread/INFO] [tombstone/]: The player Sonmipo has successfully been saved
# [23:06:42] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Sonmipo to Pd4vIn]
# [23:08:05] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo has reached the goal [Greed may lead to loss]
# [23:08:05] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo has made the advancement [Renai Circulation]
# > [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [1 apple, 1 golden_apple, 1 enchanted_golden_apple, 1 banana]
# [23:08:33] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Sonmipo to Pd4vIn]
# [23:10:08] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo has reached the goal [Home Sweet Home]
# [23:11:59] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Sonmipo to Pd4vIn]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [23:14:32] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Sonmipo to Pd4vIn]
# [23:16:14] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Pd4vIn to Sonmipo]
# [23:16:53] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: Sonmipo lost connection: Disconnected
# [23:16:53] [Server thread/INFO] [minecraft/DedicatedServer]: Sonmipo left the game
# [23:17:09] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Set own game mode to Creative Mode]
# [23:20:45] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 3915ms or 78 ticks behind
# [23:23:18] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Pd4vIn to 5614.500000, 111.500000, 38.500000]
# [23:23:18] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 3205ms or 64 ticks behind
# [23:23:44] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Pd4vIn to 5656.500000, 149.500000, 426.500000]
# > [23:23:52] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2001ms or 40 ticks behind
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [23:24:30] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Kicked owen: Kicked by an operator]
# [23:24:30] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: owen lost connection: Kicked by an operator
# [23:24:30] [Server thread/INFO] [minecraft/DedicatedServer]: owen left the game
# [23:26:36] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Teleported Pd4vIn to 1542.500000, 96.500000, -260.500000]
# [23:26:45] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2003ms or 40 ticks behind
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [23:36:06] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Set the weather to clear]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [23:48:40] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Set own game mode to Survival Mode]
# [23:48:46] [Server thread/INFO] [minecraft/DedicatedServer]: [Pd4vIn: Set the time to 1000]
# [23:48:54] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: Pd4vIn lost connection: Disconnected
# [23:48:54] [Server thread/INFO] [minecraft/DedicatedServer]: Pd4vIn left the game
# >
# >[23:49:28] [Server console handler/ERROR] [minecraft/DedicatedServer]: Caught previously unhandled exception :
# java.io.IOError: java.io.InterruptedIOException: Command interrupted
# 	at org.jline.terminal.impl.AbstractPosixTerminal.setAttributes(AbstractPosixTerminal.java:54) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.reader.impl.LineReaderImpl.readLine(LineReaderImpl.java:650) ~[jline-reader-3.12.1.jar%2312!/:?] {}
# 	at org.jline.reader.impl.LineReaderImpl.readLine(LineReaderImpl.java:418) ~[jline-reader-3.12.1.jar%2312!/:?] {}
# 	at net.minecraftforge.server.console.TerminalHandler.handleCommands(TerminalHandler.java:46) ~[forge-1.18.2-40.2.17-universal.jar%23117!/:?] {re:classloading}
# 	at net.minecraft.server.dedicated.DedicatedServer$1.run(DedicatedServer.java:92) ~[server-1.18.2-20220404.173914-srg.jar%23112!/:?] {re:classloading}
# Caused by: java.io.InterruptedIOException: Command interrupted
# 	at org.jline.utils.ExecHelper.exec(ExecHelper.java:46) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.ExecPty.doGetConfig(ExecPty.java:175) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.ExecPty.getAttr(ExecPty.java:87) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.ExecPty.doSetAttr(ExecPty.java:93) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.AbstractPty.setAttr(AbstractPty.java:29) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.AbstractPosixTerminal.setAttributes(AbstractPosixTerminal.java:52) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	... 4 more
# Caused by: java.lang.InterruptedException
# 	at java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.await(AbstractQueuedSynchronizer.java:1691) ~[?:?] {}
# 	at java.lang.ProcessImpl.waitFor(ProcessImpl.java:425) ~[?:?] {}
# 	at org.jline.utils.ExecHelper.waitAndCapture(ExecHelper.java:66) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.utils.ExecHelper.exec(ExecHelper.java:36) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.ExecPty.doGetConfig(ExecPty.java:175) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.ExecPty.getAttr(ExecPty.java:87) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.ExecPty.doSetAttr(ExecPty.java:93) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.AbstractPty.setAttr(AbstractPty.java:29) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	at org.jline.terminal.impl.AbstractPosixTerminal.setAttributes(AbstractPosixTerminal.java:52) ~[jline-terminal-3.12.1.jar%2313!/:?] {}
# 	... 4 more
